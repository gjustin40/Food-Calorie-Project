# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

from sklearn.model_selection import train_test_split, KFold

import matplotlib.pyplot as plt
import numpy as np
import time
import os
from PIL import Image




# %matplotlib inline

# %%
def train_test_dataset(dataset, val=False, test_split=0.25):
    train_idx, test_idx = train_test_split(list(range(len(dataset))), test_size=test_split)
    datasets = {}
    datasets['train'] = torch.utils.data.Subset(dataset, train_idx)
    datasets['test'] = torch.utils.data.Subset(dataset, test_idx)
    
    return datasets

def show_img(data, size=8, shape=(4,2), pred=False):
    images_tensor, labels_tensor = data
    images_tensor, labels_tensor = images_tensor[:size], labels_tensor[:size]
    
    plt.figure(figsize=(10,10))
    row, col = shape
    for i, im in enumerate(images_tensor):
        images_tensor[i] = inv_normalize(im)
        images_numpy = np.array(images_tensor[i].permute(1,2,0))
        class_name = label_to_name[labels_tensor[i].item()]
        
        plt.subplot(row, col, i+1)
        plt.axis('off')
        plt.imshow(images_numpy)
        plt.title(class_name)

# %%
k_folds = 5
EPOCH = 80
TRAIN_BATCH_SIZE = 32
TEST_BATCH_SIZE = 8
TEST_SIZE = 0.20
LEARNING_RATE = 0.001
MOMENTUM = 0.9

torch.manual_seed(42)

# %%
transform = transforms.Compose([
    transforms.Resize((200,200)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomAffine(30),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

inv_normalize = transforms.Normalize(
   mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
   std=[1/0.229, 1/0.224, 1/0.225]
)

data_path = '../../data/caffe_drinks/'
print('Name of Class : ', os.listdir(data_path))

datasets = torchvision.datasets.ImageFolder(root=data_path, transform=transform)

kfold = KFold(n_splits=k_folds, shuffle=True)

CLASS_NUM = len(os.listdir(data_path))
print('Number of class : ', CLASS_NUM)

label_to_name = {v:k for k,v in datasets.class_to_idx.items()}
print('Label to Name : ', label_to_name)

# show_img(iter(trainloader).next(), size=9, shape=(3,3))
# Out:
# Name of Class :  ['americano', 'bubbletea_blacksugar', 'cappuccino', 'caramel_macchiato', 'frappuccino_javachip', 'latte_goguma', 'latte_greentea', 'latte_Strawberry', 'mango_juice']
# Number of class :  9
# Label to Name :  {0: 'americano', 1: 'bubbletea_blacksugar', 2: 'cappuccino', 3: 'caramel_macchiato', 4: 'frappuccino_javachip', 5: 'latte_Strawberry', 6: 'latte_goguma', 7: 'latte_greentea', 8: 'mango_juice'}

# %%
loss_for_flod = []
results = {}
for fold, (train_ids, test_ids) in enumerate(kfold.split(datasets), 1):

    print(f'FOLD {fold}')
    print('---------------------------')

    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)

    trainloader = torch.utils.data.DataLoader(datasets, batch_size=TRAIN_BATCH_SIZE, sampler=train_subsampler)
    testloader = torch.utils.data.DataLoader(datasets, batch_size=TEST_BATCH_SIZE, sampler=test_subsampler)
    
    model = torchvision.models.resnet152(pretrained=True)
    for p in model.parameters():
        p.requires_grad = False
    model.fc = nn.Linear(2048, CLASS_NUM)
    
    # GPU 여부
    if torch.cuda.is_available():
        device = torch.device('cuda')
        print('We are using GPU')
    else:
        device = torch.device('cpu')
        print('We are using CPU')
        
    loss_func = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
    
    loss_for_epoch = []
    model.train()
    for e in range(EPOCH):
        start_time = time.time()

        model.to(device)

        running_loss = 0
        for i, data in enumerate(trainloader):
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_func(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss
            now = time.time()
            time_cost = now - start_time
            print('\rEpoch : [%d/%d]----- Iter : [%d/%d] ----- LOSS : %.3f------ Time : %d' 
                  %(e+1, EPOCH, i+1, len(trainloader), running_loss, time_cost), end='')

        if e == 0:
            print('\nThe Prediction of Total Time : %s' %time.strftime("%H:%M:%S", time.gmtime(time_cost*EPOCH)))

        print('\n')
        loss_for_epoch.append(running_loss)
    
    print('Starting testing')
    
    save_path = f'weights/model-fold-{fold}.pth'
    torch.save(model.state_dict(), save_path)
    
    correct, total = 0, 0
    model.eval()
    with torch.no_grad():
        # Iterate over the test data and generate predictions
        for i, data in enumerate(testloader):

            # Get inputs
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)

            # Generate outputs
            outputs = model(inputs)

            # Set total and correct
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    # Print accuracy
    print('Accuracy for fold %d: %d %%' % (fold, 100.0 * correct / total))
    print('--------------------------------')
    results[fold] = 100.0 * (correct / total)
# Out:
# FOLD 1
# ---------------------------
# We are using GPU
# Epoch : [1/80]----- Iter : [109/109] ----- LOSS : 168.386------ Time : 25
# The Prediction of Total Time : 00:34:35
#
#
# Epoch : [2/80]----- Iter : [109/109] ----- LOSS : 98.238------ Time : 23
#
# Epoch : [3/80]----- Iter : [109/109] ----- LOSS : 77.980------ Time : 23
#
# Epoch : [4/80]----- Iter : [109/109] ----- LOSS : 68.198------ Time : 23
#
# Epoch : [5/80]----- Iter : [109/109] ----- LOSS : 63.640------ Time : 23
#
# Epoch : [6/80]----- Iter : [109/109] ----- LOSS : 59.817------ Time : 23
#
# Epoch : [7/80]----- Iter : [109/109] ----- LOSS : 55.338------ Time : 24
#
# Epoch : [8/80]----- Iter : [109/109] ----- LOSS : 53.367------ Time : 24
#
# Epoch : [9/80]----- Iter : [109/109] ----- LOSS : 52.202------ Time : 24
#
# Epoch : [10/80]----- Iter : [109/109] ----- LOSS : 49.799------ Time : 24
#
# Epoch : [11/80]----- Iter : [109/109] ----- LOSS : 47.877------ Time : 24
#
# Epoch : [12/80]----- Iter : [109/109] ----- LOSS : 46.931------ Time : 24
#
# Epoch : [13/80]----- Iter : [109/109] ----- LOSS : 47.110------ Time : 24
#
# Epoch : [14/80]----- Iter : [109/109] ----- LOSS : 45.756------ Time : 24
#
# Epoch : [15/80]----- Iter : [109/109] ----- LOSS : 45.222------ Time : 24
#
# Epoch : [16/80]----- Iter : [109/109] ----- LOSS : 43.845------ Time : 24
#
# Epoch : [17/80]----- Iter : [109/109] ----- LOSS : 42.780------ Time : 24
#
# Epoch : [18/80]----- Iter : [109/109] ----- LOSS : 43.932------ Time : 24
#
# Epoch : [19/80]----- Iter : [109/109] ----- LOSS : 41.433------ Time : 24
#
# Epoch : [20/80]----- Iter : [109/109] ----- LOSS : 42.542------ Time : 24
#
# Epoch : [21/80]----- Iter : [109/109] ----- LOSS : 41.605------ Time : 24
#
# Epoch : [22/80]----- Iter : [109/109] ----- LOSS : 39.692------ Time : 24
#
# Epoch : [23/80]----- Iter : [109/109] ----- LOSS : 41.321------ Time : 24
#
# Epoch : [24/80]----- Iter : [109/109] ----- LOSS : 39.656------ Time : 24
#
# Epoch : [25/80]----- Iter : [109/109] ----- LOSS : 39.928------ Time : 24
#
# Epoch : [26/80]----- Iter : [109/109] ----- LOSS : 37.523------ Time : 24
#
# Epoch : [27/80]----- Iter : [109/109] ----- LOSS : 39.715------ Time : 24
#
# Epoch : [28/80]----- Iter : [109/109] ----- LOSS : 38.471------ Time : 23
#
# Epoch : [29/80]----- Iter : [109/109] ----- LOSS : 38.259------ Time : 24
#
# Epoch : [30/80]----- Iter : [109/109] ----- LOSS : 36.471------ Time : 24
#
# Epoch : [31/80]----- Iter : [109/109] ----- LOSS : 37.561------ Time : 24
#
# Epoch : [32/80]----- Iter : [109/109] ----- LOSS : 36.789------ Time : 23
#
# Epoch : [33/80]----- Iter : [109/109] ----- LOSS : 35.698------ Time : 24
#
# Epoch : [34/80]----- Iter : [109/109] ----- LOSS : 38.097------ Time : 24
#
# Epoch : [35/80]----- Iter : [109/109] ----- LOSS : 36.856------ Time : 24
#
# Epoch : [36/80]----- Iter : [109/109] ----- LOSS : 37.438------ Time : 24
#
# Epoch : [37/80]----- Iter : [109/109] ----- LOSS : 35.102------ Time : 24
#
# Epoch : [38/80]----- Iter : [109/109] ----- LOSS : 35.326------ Time : 23
#
# Epoch : [39/80]----- Iter : [109/109] ----- LOSS : 35.141------ Time : 23
#
# Epoch : [40/80]----- Iter : [109/109] ----- LOSS : 34.748------ Time : 23
#
# Epoch : [41/80]----- Iter : [109/109] ----- LOSS : 36.644------ Time : 23
#
# Epoch : [42/80]----- Iter : [109/109] ----- LOSS : 33.465------ Time : 23
#
# Epoch : [43/80]----- Iter : [109/109] ----- LOSS : 35.670------ Time : 23
#
# Epoch : [44/80]----- Iter : [109/109] ----- LOSS : 33.693------ Time : 23
#
# Epoch : [45/80]----- Iter : [109/109] ----- LOSS : 34.267------ Time : 23
#
# Epoch : [46/80]----- Iter : [109/109] ----- LOSS : 34.887------ Time : 23
#
# Epoch : [47/80]----- Iter : [109/109] ----- LOSS : 35.191------ Time : 23
#
# Epoch : [48/80]----- Iter : [109/109] ----- LOSS : 32.410------ Time : 23
#
# Epoch : [49/80]----- Iter : [109/109] ----- LOSS : 31.549------ Time : 23
#
# Epoch : [50/80]----- Iter : [109/109] ----- LOSS : 34.861------ Time : 23
#
# Epoch : [51/80]----- Iter : [109/109] ----- LOSS : 35.719------ Time : 24
#
# Epoch : [52/80]----- Iter : [109/109] ----- LOSS : 32.603------ Time : 23
#
# Epoch : [53/80]----- Iter : [109/109] ----- LOSS : 32.107------ Time : 23
#
# Epoch : [54/80]----- Iter : [109/109] ----- LOSS : 33.380------ Time : 24
#
# Epoch : [55/80]----- Iter : [109/109] ----- LOSS : 33.253------ Time : 24
#
# Epoch : [56/80]----- Iter : [109/109] ----- LOSS : 32.784------ Time : 23
#
# Epoch : [57/80]----- Iter : [109/109] ----- LOSS : 34.224------ Time : 24
#
# Epoch : [58/80]----- Iter : [109/109] ----- LOSS : 33.338------ Time : 23
#
# Epoch : [59/80]----- Iter : [109/109] ----- LOSS : 33.361------ Time : 24
#
# Epoch : [60/80]----- Iter : [109/109] ----- LOSS : 32.963------ Time : 24
#
# Epoch : [61/80]----- Iter : [109/109] ----- LOSS : 32.495------ Time : 24
#
# Epoch : [62/80]----- Iter : [109/109] ----- LOSS : 31.614------ Time : 24
#
# Epoch : [63/80]----- Iter : [109/109] ----- LOSS : 33.614------ Time : 24
#
# Epoch : [64/80]----- Iter : [109/109] ----- LOSS : 32.389------ Time : 24
#
# Epoch : [65/80]----- Iter : [109/109] ----- LOSS : 32.015------ Time : 23
#
# Epoch : [66/80]----- Iter : [109/109] ----- LOSS : 29.938------ Time : 23
#
# Epoch : [67/80]----- Iter : [109/109] ----- LOSS : 31.005------ Time : 24
#
# Epoch : [68/80]----- Iter : [109/109] ----- LOSS : 31.378------ Time : 24
#
# Epoch : [69/80]----- Iter : [109/109] ----- LOSS : 33.098------ Time : 24
#
# Epoch : [70/80]----- Iter : [109/109] ----- LOSS : 30.527------ Time : 23
#
# Epoch : [71/80]----- Iter : [109/109] ----- LOSS : 33.147------ Time : 23
#
# Epoch : [72/80]----- Iter : [109/109] ----- LOSS : 32.204------ Time : 23
#
# Epoch : [73/80]----- Iter : [109/109] ----- LOSS : 29.499------ Time : 23
#
# Epoch : [74/80]----- Iter : [109/109] ----- LOSS : 30.115------ Time : 24
#
# Epoch : [75/80]----- Iter : [109/109] ----- LOSS : 30.698------ Time : 24
#
# Epoch : [76/80]----- Iter : [109/109] ----- LOSS : 30.944------ Time : 24
#
# Epoch : [77/80]----- Iter : [109/109] ----- LOSS : 30.704------ Time : 23
#
# Epoch : [78/80]----- Iter : [109/109] ----- LOSS : 31.345------ Time : 24
#
# Epoch : [79/80]----- Iter : [109/109] ----- LOSS : 30.190------ Time : 24
#
# Epoch : [80/80]----- Iter : [109/109] ----- LOSS : 29.846------ Time : 24
#
# Starting testing
# Accuracy for fold 1: 87 %
# --------------------------------
# FOLD 2
# ---------------------------
# We are using GPU
# Epoch : [1/80]----- Iter : [109/109] ----- LOSS : 169.920------ Time : 24
# The Prediction of Total Time : 00:32:13
#
#
# Epoch : [2/80]----- Iter : [109/109] ----- LOSS : 96.909------ Time : 23
#
# Epoch : [3/80]----- Iter : [109/109] ----- LOSS : 75.704------ Time : 24
#
# Epoch : [4/80]----- Iter : [109/109] ----- LOSS : 67.902------ Time : 24
#
# Epoch : [5/80]----- Iter : [109/109] ----- LOSS : 59.912------ Time : 24
#
# Epoch : [6/80]----- Iter : [109/109] ----- LOSS : 58.548------ Time : 24
#
# Epoch : [7/80]----- Iter : [109/109] ----- LOSS : 54.848------ Time : 23
#
# Epoch : [8/80]----- Iter : [109/109] ----- LOSS : 52.580------ Time : 23
#
# Epoch : [9/80]----- Iter : [109/109] ----- LOSS : 51.876------ Time : 24
#
# Epoch : [10/80]----- Iter : [109/109] ----- LOSS : 51.512------ Time : 24
#
# Epoch : [11/80]----- Iter : [109/109] ----- LOSS : 47.702------ Time : 24
#
# Epoch : [12/80]----- Iter : [109/109] ----- LOSS : 47.449------ Time : 23
#
# Epoch : [13/80]----- Iter : [109/109] ----- LOSS : 45.222------ Time : 24
#
# Epoch : [14/80]----- Iter : [109/109] ----- LOSS : 45.950------ Time : 24
#
# Epoch : [15/80]----- Iter : [109/109] ----- LOSS : 44.850------ Time : 23
#
# Epoch : [16/80]----- Iter : [109/109] ----- LOSS : 44.998------ Time : 24
#
# Epoch : [17/80]----- Iter : [109/109] ----- LOSS : 43.159------ Time : 24
#
# Epoch : [18/80]----- Iter : [109/109] ----- LOSS : 41.459------ Time : 23
#
# Epoch : [19/80]----- Iter : [109/109] ----- LOSS : 43.906------ Time : 24
#
# Epoch : [20/80]----- Iter : [109/109] ----- LOSS : 42.174------ Time : 24
#
# Epoch : [21/80]----- Iter : [109/109] ----- LOSS : 40.314------ Time : 24
#
# Epoch : [22/80]----- Iter : [109/109] ----- LOSS : 39.540------ Time : 24
#
# Epoch : [23/80]----- Iter : [109/109] ----- LOSS : 40.138------ Time : 24
#
# Epoch : [24/80]----- Iter : [109/109] ----- LOSS : 40.707------ Time : 24
#
# Epoch : [25/80]----- Iter : [109/109] ----- LOSS : 39.873------ Time : 24
# Epoch : [26/80]----- Iter : [109/109] ----- LOSS : 38.979------ Time : 24
#
# Epoch : [27/80]----- Iter : [109/109] ----- LOSS : 38.207------ Time : 24
#
# Epoch : [28/80]----- Iter : [109/109] ----- LOSS : 37.707------ Time : 24
#
# Epoch : [29/80]----- Iter : [109/109] ----- LOSS : 36.434------ Time : 24
#
# Epoch : [30/80]----- Iter : [109/109] ----- LOSS : 36.943------ Time : 24
#
# Epoch : [31/80]----- Iter : [109/109] ----- LOSS : 36.106------ Time : 24
#
# Epoch : [32/80]----- Iter : [109/109] ----- LOSS : 38.543------ Time : 25
#
# Epoch : [33/80]----- Iter : [109/109] ----- LOSS : 38.214------ Time : 24
#
# Epoch : [34/80]----- Iter : [109/109] ----- LOSS : 35.853------ Time : 24
#
# Epoch : [35/80]----- Iter : [109/109] ----- LOSS : 33.855------ Time : 24
#
# Epoch : [36/80]----- Iter : [109/109] ----- LOSS : 35.273------ Time : 23
#
# Epoch : [37/80]----- Iter : [109/109] ----- LOSS : 35.079------ Time : 24
#
# Epoch : [38/80]----- Iter : [109/109] ----- LOSS : 34.937------ Time : 24
#
# Epoch : [39/80]----- Iter : [109/109] ----- LOSS : 35.096------ Time : 23
#
# Epoch : [40/80]----- Iter : [109/109] ----- LOSS : 35.907------ Time : 24
#
# Epoch : [41/80]----- Iter : [109/109] ----- LOSS : 33.473------ Time : 24
#
# Epoch : [42/80]----- Iter : [109/109] ----- LOSS : 33.803------ Time : 24
#
# Epoch : [43/80]----- Iter : [109/109] ----- LOSS : 34.360------ Time : 24
#
# Epoch : [44/80]----- Iter : [109/109] ----- LOSS : 34.103------ Time : 24
#
# Epoch : [45/80]----- Iter : [109/109] ----- LOSS : 36.313------ Time : 24
#
# Epoch : [46/80]----- Iter : [109/109] ----- LOSS : 34.605------ Time : 24
#
# Epoch : [47/80]----- Iter : [109/109] ----- LOSS : 33.203------ Time : 24
#
# Epoch : [48/80]----- Iter : [109/109] ----- LOSS : 34.924------ Time : 24
#
# Epoch : [49/80]----- Iter : [109/109] ----- LOSS : 32.365------ Time : 24
#
# Epoch : [50/80]----- Iter : [109/109] ----- LOSS : 32.404------ Time : 24
#
# Epoch : [51/80]----- Iter : [109/109] ----- LOSS : 34.743------ Time : 24
#
# Epoch : [52/80]----- Iter : [109/109] ----- LOSS : 33.652------ Time : 24
#
# Epoch : [53/80]----- Iter : [109/109] ----- LOSS : 34.212------ Time : 24
#
# Epoch : [54/80]----- Iter : [109/109] ----- LOSS : 32.337------ Time : 24
#
# Epoch : [55/80]----- Iter : [109/109] ----- LOSS : 33.202------ Time : 24
#
# Epoch : [56/80]----- Iter : [109/109] ----- LOSS : 33.032------ Time : 24
#
# Epoch : [57/80]----- Iter : [109/109] ----- LOSS : 33.517------ Time : 24
#
# Epoch : [58/80]----- Iter : [109/109] ----- LOSS : 31.934------ Time : 24
#
# Epoch : [59/80]----- Iter : [109/109] ----- LOSS : 31.773------ Time : 24
#
# Epoch : [60/80]----- Iter : [109/109] ----- LOSS : 31.496------ Time : 24
#
# Epoch : [61/80]----- Iter : [109/109] ----- LOSS : 31.773------ Time : 24
#
# Epoch : [62/80]----- Iter : [109/109] ----- LOSS : 31.763------ Time : 24
#
# Epoch : [63/80]----- Iter : [109/109] ----- LOSS : 31.541------ Time : 23
#
# Epoch : [64/80]----- Iter : [109/109] ----- LOSS : 31.120------ Time : 24
#
# Epoch : [65/80]----- Iter : [109/109] ----- LOSS : 30.842------ Time : 24
#
# Epoch : [66/80]----- Iter : [109/109] ----- LOSS : 30.884------ Time : 23
#
# Epoch : [67/80]----- Iter : [109/109] ----- LOSS : 30.815------ Time : 23
#
# Epoch : [68/80]----- Iter : [109/109] ----- LOSS : 31.465------ Time : 23
#
# Epoch : [69/80]----- Iter : [109/109] ----- LOSS : 31.472------ Time : 23
#
# Epoch : [70/80]----- Iter : [109/109] ----- LOSS : 30.978------ Time : 23
#
# Epoch : [71/80]----- Iter : [109/109] ----- LOSS : 31.117------ Time : 23
#
# Epoch : [72/80]----- Iter : [109/109] ----- LOSS : 30.389------ Time : 23
#
# Epoch : [73/80]----- Iter : [109/109] ----- LOSS : 30.740------ Time : 24
#
# Epoch : [74/80]----- Iter : [109/109] ----- LOSS : 29.798------ Time : 24
#
# Epoch : [75/80]----- Iter : [109/109] ----- LOSS : 29.714------ Time : 24
#
# Epoch : [76/80]----- Iter : [109/109] ----- LOSS : 30.900------ Time : 24
#
# Epoch : [77/80]----- Iter : [109/109] ----- LOSS : 29.056------ Time : 24
#
# Epoch : [78/80]----- Iter : [109/109] ----- LOSS : 30.543------ Time : 24
#
# Epoch : [79/80]----- Iter : [109/109] ----- LOSS : 29.649------ Time : 24
#
# Epoch : [80/80]----- Iter : [109/109] ----- LOSS : 29.546------ Time : 24
#
# Starting testing
# Accuracy for fold 2: 88 %
# --------------------------------
# FOLD 3
# ---------------------------
# We are using GPU
# Epoch : [1/80]----- Iter : [109/109] ----- LOSS : 165.090------ Time : 24
# The Prediction of Total Time : 00:32:23
#
#
# Epoch : [2/80]----- Iter : [109/109] ----- LOSS : 93.278------ Time : 24
#
# Epoch : [3/80]----- Iter : [109/109] ----- LOSS : 76.275------ Time : 24
#
# Epoch : [4/80]----- Iter : [109/109] ----- LOSS : 65.570------ Time : 24
#
# Epoch : [5/80]----- Iter : [109/109] ----- LOSS : 62.461------ Time : 24
#
# Epoch : [6/80]----- Iter : [109/109] ----- LOSS : 58.385------ Time : 24
#
# Epoch : [7/80]----- Iter : [109/109] ----- LOSS : 54.832------ Time : 24
#
# Epoch : [8/80]----- Iter : [109/109] ----- LOSS : 51.672------ Time : 24
#
# Epoch : [9/80]----- Iter : [109/109] ----- LOSS : 51.252------ Time : 24
#
# Epoch : [10/80]----- Iter : [109/109] ----- LOSS : 50.662------ Time : 24
#
# Epoch : [11/80]----- Iter : [109/109] ----- LOSS : 47.192------ Time : 24
#
# Epoch : [12/80]----- Iter : [109/109] ----- LOSS : 45.928------ Time : 24
#
# Epoch : [13/80]----- Iter : [109/109] ----- LOSS : 46.449------ Time : 24
#
# Epoch : [14/80]----- Iter : [109/109] ----- LOSS : 47.614------ Time : 24
#
# Epoch : [15/80]----- Iter : [109/109] ----- LOSS : 42.804------ Time : 24
#
# Epoch : [16/80]----- Iter : [109/109] ----- LOSS : 43.936------ Time : 24
#
# Epoch : [17/80]----- Iter : [109/109] ----- LOSS : 42.184------ Time : 23
#
# Epoch : [18/80]----- Iter : [109/109] ----- LOSS : 42.291------ Time : 24
#
# Epoch : [19/80]----- Iter : [109/109] ----- LOSS : 41.726------ Time : 24
#
# Epoch : [20/80]----- Iter : [109/109] ----- LOSS : 42.567------ Time : 23
#
# Epoch : [21/80]----- Iter : [109/109] ----- LOSS : 40.688------ Time : 24
#
# Epoch : [22/80]----- Iter : [109/109] ----- LOSS : 40.365------ Time : 24
#
# Epoch : [23/80]----- Iter : [109/109] ----- LOSS : 39.734------ Time : 24
#
# Epoch : [24/80]----- Iter : [109/109] ----- LOSS : 40.907------ Time : 24
#
# Epoch : [25/80]----- Iter : [109/109] ----- LOSS : 38.441------ Time : 24
#
# Epoch : [26/80]----- Iter : [109/109] ----- LOSS : 39.073------ Time : 24
#
# Epoch : [27/80]----- Iter : [109/109] ----- LOSS : 38.945------ Time : 24
#
# Epoch : [28/80]----- Iter : [109/109] ----- LOSS : 37.167------ Time : 24
#
# Epoch : [29/80]----- Iter : [109/109] ----- LOSS : 37.743------ Time : 24
#
# Epoch : [30/80]----- Iter : [109/109] ----- LOSS : 37.780------ Time : 24
#
# Epoch : [31/80]----- Iter : [109/109] ----- LOSS : 37.643------ Time : 24
#
# Epoch : [32/80]----- Iter : [109/109] ----- LOSS : 37.877------ Time : 24
#
# Epoch : [33/80]----- Iter : [109/109] ----- LOSS : 37.686------ Time : 24
#
# Epoch : [34/80]----- Iter : [109/109] ----- LOSS : 36.391------ Time : 24
#
# Epoch : [35/80]----- Iter : [109/109] ----- LOSS : 37.540------ Time : 24
#
# Epoch : [36/80]----- Iter : [109/109] ----- LOSS : 36.464------ Time : 24
#
# Epoch : [37/80]----- Iter : [109/109] ----- LOSS : 34.990------ Time : 24
#
# Epoch : [38/80]----- Iter : [109/109] ----- LOSS : 35.930------ Time : 24
#
# Epoch : [39/80]----- Iter : [109/109] ----- LOSS : 36.180------ Time : 24
#
# Epoch : [40/80]----- Iter : [109/109] ----- LOSS : 35.658------ Time : 24
#
# Epoch : [41/80]----- Iter : [109/109] ----- LOSS : 35.018------ Time : 24
#
# Epoch : [42/80]----- Iter : [109/109] ----- LOSS : 36.032------ Time : 24
#
# Epoch : [43/80]----- Iter : [109/109] ----- LOSS : 34.054------ Time : 24
#
# Epoch : [44/80]----- Iter : [109/109] ----- LOSS : 34.429------ Time : 24
#
# Epoch : [45/80]----- Iter : [109/109] ----- LOSS : 34.210------ Time : 24
#
# Epoch : [46/80]----- Iter : [109/109] ----- LOSS : 35.567------ Time : 24
#
# Epoch : [47/80]----- Iter : [109/109] ----- LOSS : 34.581------ Time : 24
#
# Epoch : [48/80]----- Iter : [109/109] ----- LOSS : 33.032------ Time : 24
#
# Epoch : [49/80]----- Iter : [109/109] ----- LOSS : 33.058------ Time : 24
#
# Epoch : [50/80]----- Iter : [109/109] ----- LOSS : 32.755------ Time : 24
#
# Epoch : [51/80]----- Iter : [109/109] ----- LOSS : 33.038------ Time : 24
#
# Epoch : [52/80]----- Iter : [109/109] ----- LOSS : 33.774------ Time : 24
# Epoch : [53/80]----- Iter : [109/109] ----- LOSS : 34.601------ Time : 24
#
# Epoch : [54/80]----- Iter : [109/109] ----- LOSS : 31.052------ Time : 24
#
# Epoch : [55/80]----- Iter : [109/109] ----- LOSS : 32.366------ Time : 24
#
# Epoch : [56/80]----- Iter : [109/109] ----- LOSS : 32.003------ Time : 24
#
# Epoch : [57/80]----- Iter : [109/109] ----- LOSS : 32.639------ Time : 24
#
# Epoch : [58/80]----- Iter : [109/109] ----- LOSS : 32.342------ Time : 24
#
# Epoch : [59/80]----- Iter : [109/109] ----- LOSS : 32.912------ Time : 24
#
# Epoch : [60/80]----- Iter : [109/109] ----- LOSS : 32.255------ Time : 24
#
# Epoch : [61/80]----- Iter : [109/109] ----- LOSS : 31.491------ Time : 24
#
# Epoch : [62/80]----- Iter : [109/109] ----- LOSS : 32.448------ Time : 24
#
# Epoch : [63/80]----- Iter : [109/109] ----- LOSS : 31.369------ Time : 24
#
# Epoch : [64/80]----- Iter : [109/109] ----- LOSS : 33.412------ Time : 24
#
# Epoch : [65/80]----- Iter : [109/109] ----- LOSS : 32.660------ Time : 24
#
# Epoch : [66/80]----- Iter : [109/109] ----- LOSS : 31.982------ Time : 24
#
# Epoch : [67/80]----- Iter : [109/109] ----- LOSS : 30.992------ Time : 23
#
# Epoch : [68/80]----- Iter : [109/109] ----- LOSS : 29.957------ Time : 23
#
# Epoch : [69/80]----- Iter : [109/109] ----- LOSS : 31.860------ Time : 23
#
# Epoch : [70/80]----- Iter : [109/109] ----- LOSS : 31.748------ Time : 23
#
# Epoch : [71/80]----- Iter : [109/109] ----- LOSS : 31.092------ Time : 24
#
# Epoch : [72/80]----- Iter : [109/109] ----- LOSS : 30.200------ Time : 24
#
# Epoch : [73/80]----- Iter : [109/109] ----- LOSS : 30.075------ Time : 24
#
# Epoch : [74/80]----- Iter : [109/109] ----- LOSS : 29.315------ Time : 24
#
# Epoch : [75/80]----- Iter : [109/109] ----- LOSS : 30.043------ Time : 24
#
# Epoch : [76/80]----- Iter : [109/109] ----- LOSS : 30.848------ Time : 24
#
# Epoch : [77/80]----- Iter : [109/109] ----- LOSS : 29.399------ Time : 24
#
# Epoch : [78/80]----- Iter : [109/109] ----- LOSS : 29.929------ Time : 24
#
# Epoch : [79/80]----- Iter : [109/109] ----- LOSS : 30.118------ Time : 24
#
# Epoch : [80/80]----- Iter : [109/109] ----- LOSS : 31.887------ Time : 24
#
# Starting testing
# Accuracy for fold 3: 87 %
# --------------------------------
# FOLD 4
# ---------------------------
# We are using GPU
# Epoch : [1/80]----- Iter : [109/109] ----- LOSS : 168.056------ Time : 24
# The Prediction of Total Time : 00:32:23
#
#
# Epoch : [2/80]----- Iter : [109/109] ----- LOSS : 95.668------ Time : 24
#
# Epoch : [3/80]----- Iter : [109/109] ----- LOSS : 78.077------ Time : 24
#
# Epoch : [4/80]----- Iter : [109/109] ----- LOSS : 68.757------ Time : 23
#
# Epoch : [5/80]----- Iter : [109/109] ----- LOSS : 62.588------ Time : 23
#
# Epoch : [6/80]----- Iter : [109/109] ----- LOSS : 56.922------ Time : 24
#
# Epoch : [7/80]----- Iter : [109/109] ----- LOSS : 56.410------ Time : 23
#
# Epoch : [8/80]----- Iter : [109/109] ----- LOSS : 52.602------ Time : 23
#
# Epoch : [9/80]----- Iter : [109/109] ----- LOSS : 51.430------ Time : 24
#
# Epoch : [10/80]----- Iter : [109/109] ----- LOSS : 49.241------ Time : 24
#
# Epoch : [11/80]----- Iter : [109/109] ----- LOSS : 48.735------ Time : 24
#
# Epoch : [12/80]----- Iter : [109/109] ----- LOSS : 45.874------ Time : 24
#
# Epoch : [13/80]----- Iter : [109/109] ----- LOSS : 45.685------ Time : 24
#
# Epoch : [14/80]----- Iter : [109/109] ----- LOSS : 48.162------ Time : 24
#
# Epoch : [15/80]----- Iter : [109/109] ----- LOSS : 45.218------ Time : 24
#
# Epoch : [16/80]----- Iter : [109/109] ----- LOSS : 44.419------ Time : 24
#
# Epoch : [17/80]----- Iter : [109/109] ----- LOSS : 43.855------ Time : 24
#
# Epoch : [18/80]----- Iter : [109/109] ----- LOSS : 42.521------ Time : 24
#
# Epoch : [19/80]----- Iter : [109/109] ----- LOSS : 41.432------ Time : 24
#
# Epoch : [20/80]----- Iter : [109/109] ----- LOSS : 41.957------ Time : 24
#
# Epoch : [21/80]----- Iter : [109/109] ----- LOSS : 40.846------ Time : 24
#
# Epoch : [22/80]----- Iter : [109/109] ----- LOSS : 39.648------ Time : 24
#
# Epoch : [23/80]----- Iter : [109/109] ----- LOSS : 41.834------ Time : 24
#
# Epoch : [24/80]----- Iter : [109/109] ----- LOSS : 40.954------ Time : 24
#
# Epoch : [25/80]----- Iter : [109/109] ----- LOSS : 41.306------ Time : 23
#
# Epoch : [26/80]----- Iter : [109/109] ----- LOSS : 38.384------ Time : 24
#
# Epoch : [27/80]----- Iter : [109/109] ----- LOSS : 38.344------ Time : 24
#
# Epoch : [28/80]----- Iter : [109/109] ----- LOSS : 38.744------ Time : 24
#
# Epoch : [29/80]----- Iter : [109/109] ----- LOSS : 39.300------ Time : 24
#
# Epoch : [30/80]----- Iter : [109/109] ----- LOSS : 37.481------ Time : 23
#
# Epoch : [31/80]----- Iter : [109/109] ----- LOSS : 36.988------ Time : 23
#
# Epoch : [32/80]----- Iter : [109/109] ----- LOSS : 38.026------ Time : 24
#
# Epoch : [33/80]----- Iter : [109/109] ----- LOSS : 38.048------ Time : 24
#
# Epoch : [34/80]----- Iter : [109/109] ----- LOSS : 35.430------ Time : 23
#
# Epoch : [35/80]----- Iter : [109/109] ----- LOSS : 36.637------ Time : 24
#
# Epoch : [36/80]----- Iter : [109/109] ----- LOSS : 37.891------ Time : 23
#
# Epoch : [37/80]----- Iter : [109/109] ----- LOSS : 36.511------ Time : 24
#
# Epoch : [38/80]----- Iter : [109/109] ----- LOSS : 36.271------ Time : 23
#
# Epoch : [39/80]----- Iter : [109/109] ----- LOSS : 35.934------ Time : 24
#
# Epoch : [40/80]----- Iter : [109/109] ----- LOSS : 35.755------ Time : 23
#
# Epoch : [41/80]----- Iter : [109/109] ----- LOSS : 32.537------ Time : 24
#
# Epoch : [42/80]----- Iter : [109/109] ----- LOSS : 34.247------ Time : 24
#
# Epoch : [43/80]----- Iter : [109/109] ----- LOSS : 34.032------ Time : 24
#
# Epoch : [44/80]----- Iter : [109/109] ----- LOSS : 34.635------ Time : 24
#
# Epoch : [45/80]----- Iter : [109/109] ----- LOSS : 34.882------ Time : 24
#
# Epoch : [46/80]----- Iter : [109/109] ----- LOSS : 35.237------ Time : 24
#
# Epoch : [47/80]----- Iter : [109/109] ----- LOSS : 34.070------ Time : 24
#
# Epoch : [48/80]----- Iter : [109/109] ----- LOSS : 35.153------ Time : 24
#
# Epoch : [49/80]----- Iter : [109/109] ----- LOSS : 32.645------ Time : 24
#
# Epoch : [50/80]----- Iter : [109/109] ----- LOSS : 33.051------ Time : 24
#
# Epoch : [51/80]----- Iter : [109/109] ----- LOSS : 34.257------ Time : 25
#
# Epoch : [52/80]----- Iter : [109/109] ----- LOSS : 33.848------ Time : 28
#
# Epoch : [53/80]----- Iter : [109/109] ----- LOSS : 35.144------ Time : 27
#
# Epoch : [54/80]----- Iter : [109/109] ----- LOSS : 33.305------ Time : 27
#
# Epoch : [55/80]----- Iter : [109/109] ----- LOSS : 33.776------ Time : 27
#
# Epoch : [56/80]----- Iter : [109/109] ----- LOSS : 33.203------ Time : 27
#
# Epoch : [57/80]----- Iter : [109/109] ----- LOSS : 33.548------ Time : 26
#
# Epoch : [58/80]----- Iter : [109/109] ----- LOSS : 33.843------ Time : 23
#
# Epoch : [59/80]----- Iter : [109/109] ----- LOSS : 32.490------ Time : 24
#
# Epoch : [60/80]----- Iter : [109/109] ----- LOSS : 32.216------ Time : 23
#
# Epoch : [61/80]----- Iter : [109/109] ----- LOSS : 31.453------ Time : 24
#
# Epoch : [62/80]----- Iter : [109/109] ----- LOSS : 31.985------ Time : 24
#
# Epoch : [63/80]----- Iter : [109/109] ----- LOSS : 32.952------ Time : 24
#
# Epoch : [64/80]----- Iter : [109/109] ----- LOSS : 34.511------ Time : 24
#
# Epoch : [65/80]----- Iter : [109/109] ----- LOSS : 30.481------ Time : 24
#
# Epoch : [66/80]----- Iter : [109/109] ----- LOSS : 31.257------ Time : 24
#
# Epoch : [67/80]----- Iter : [109/109] ----- LOSS : 32.998------ Time : 24
#
# Epoch : [68/80]----- Iter : [109/109] ----- LOSS : 31.893------ Time : 24
#
# Epoch : [69/80]----- Iter : [109/109] ----- LOSS : 30.638------ Time : 24
#
# Epoch : [70/80]----- Iter : [109/109] ----- LOSS : 31.478------ Time : 24
#
# Epoch : [71/80]----- Iter : [109/109] ----- LOSS : 31.381------ Time : 24
#
# Epoch : [72/80]----- Iter : [109/109] ----- LOSS : 30.724------ Time : 24
#
# Epoch : [73/80]----- Iter : [109/109] ----- LOSS : 30.461------ Time : 24
#
# Epoch : [74/80]----- Iter : [109/109] ----- LOSS : 31.105------ Time : 24
#
# Epoch : [75/80]----- Iter : [109/109] ----- LOSS : 30.352------ Time : 24
#
# Epoch : [76/80]----- Iter : [109/109] ----- LOSS : 32.891------ Time : 24
#
# Epoch : [77/80]----- Iter : [109/109] ----- LOSS : 31.697------ Time : 24
#
# Epoch : [78/80]----- Iter : [109/109] ----- LOSS : 30.644------ Time : 24
#
# Epoch : [79/80]----- Iter : [109/109] ----- LOSS : 30.819------ Time : 24
# Epoch : [80/80]----- Iter : [109/109] ----- LOSS : 30.962------ Time : 24
#
# Starting testing
# Accuracy for fold 4: 88 %
# --------------------------------
# FOLD 5
# ---------------------------
# We are using GPU
# Epoch : [1/80]----- Iter : [109/109] ----- LOSS : 169.641------ Time : 24
# The Prediction of Total Time : 00:32:48
#
#
# Epoch : [2/80]----- Iter : [109/109] ----- LOSS : 97.686------ Time : 24
#
# Epoch : [3/80]----- Iter : [109/109] ----- LOSS : 77.027------ Time : 24
#
# Epoch : [4/80]----- Iter : [109/109] ----- LOSS : 67.495------ Time : 24
#
# Epoch : [5/80]----- Iter : [109/109] ----- LOSS : 63.100------ Time : 24
#
# Epoch : [6/80]----- Iter : [109/109] ----- LOSS : 59.262------ Time : 24
#
# Epoch : [7/80]----- Iter : [109/109] ----- LOSS : 54.783------ Time : 23
#
# Epoch : [8/80]----- Iter : [109/109] ----- LOSS : 55.081------ Time : 24
#
# Epoch : [9/80]----- Iter : [109/109] ----- LOSS : 50.963------ Time : 23
#
# Epoch : [10/80]----- Iter : [109/109] ----- LOSS : 50.118------ Time : 24
#
# Epoch : [11/80]----- Iter : [109/109] ----- LOSS : 47.728------ Time : 24
#
# Epoch : [12/80]----- Iter : [109/109] ----- LOSS : 47.135------ Time : 24
#
# Epoch : [13/80]----- Iter : [109/109] ----- LOSS : 45.174------ Time : 24
#
# Epoch : [14/80]----- Iter : [109/109] ----- LOSS : 45.224------ Time : 24
#
# Epoch : [15/80]----- Iter : [109/109] ----- LOSS : 46.671------ Time : 24
#
# Epoch : [16/80]----- Iter : [109/109] ----- LOSS : 42.738------ Time : 24
#
# Epoch : [17/80]----- Iter : [109/109] ----- LOSS : 43.613------ Time : 24
#
# Epoch : [18/80]----- Iter : [109/109] ----- LOSS : 42.858------ Time : 24
#
# Epoch : [19/80]----- Iter : [109/109] ----- LOSS : 42.940------ Time : 24
#
# Epoch : [20/80]----- Iter : [109/109] ----- LOSS : 40.681------ Time : 24
#
# Epoch : [21/80]----- Iter : [109/109] ----- LOSS : 40.810------ Time : 24
#
# Epoch : [22/80]----- Iter : [109/109] ----- LOSS : 39.492------ Time : 24
#
# Epoch : [23/80]----- Iter : [109/109] ----- LOSS : 39.402------ Time : 24
#
# Epoch : [24/80]----- Iter : [109/109] ----- LOSS : 38.823------ Time : 24
#
# Epoch : [25/80]----- Iter : [109/109] ----- LOSS : 39.453------ Time : 24
#
# Epoch : [26/80]----- Iter : [109/109] ----- LOSS : 38.254------ Time : 24
#
# Epoch : [27/80]----- Iter : [109/109] ----- LOSS : 39.024------ Time : 24
#
# Epoch : [28/80]----- Iter : [109/109] ----- LOSS : 37.503------ Time : 24
#
# Epoch : [29/80]----- Iter : [109/109] ----- LOSS : 35.902------ Time : 23
#
# Epoch : [30/80]----- Iter : [109/109] ----- LOSS : 38.142------ Time : 24
#
# Epoch : [31/80]----- Iter : [109/109] ----- LOSS : 36.886------ Time : 24
#
# Epoch : [32/80]----- Iter : [109/109] ----- LOSS : 35.489------ Time : 23
#
# Epoch : [33/80]----- Iter : [109/109] ----- LOSS : 35.653------ Time : 24
#
# Epoch : [34/80]----- Iter : [109/109] ----- LOSS : 36.169------ Time : 24
#
# Epoch : [35/80]----- Iter : [109/109] ----- LOSS : 36.929------ Time : 25
#
# Epoch : [36/80]----- Iter : [109/109] ----- LOSS : 35.246------ Time : 24
#
# Epoch : [37/80]----- Iter : [109/109] ----- LOSS : 34.699------ Time : 24
#
# Epoch : [38/80]----- Iter : [109/109] ----- LOSS : 36.608------ Time : 24
#
# Epoch : [39/80]----- Iter : [109/109] ----- LOSS : 35.562------ Time : 24
#
# Epoch : [40/80]----- Iter : [109/109] ----- LOSS : 33.829------ Time : 24
#
# Epoch : [41/80]----- Iter : [109/109] ----- LOSS : 33.469------ Time : 24
#
# Epoch : [42/80]----- Iter : [109/109] ----- LOSS : 35.224------ Time : 24
#
# Epoch : [43/80]----- Iter : [109/109] ----- LOSS : 33.171------ Time : 24
#
# Epoch : [44/80]----- Iter : [109/109] ----- LOSS : 34.856------ Time : 24
#
# Epoch : [45/80]----- Iter : [109/109] ----- LOSS : 33.810------ Time : 24
#
# Epoch : [46/80]----- Iter : [109/109] ----- LOSS : 32.522------ Time : 24
#
# Epoch : [47/80]----- Iter : [109/109] ----- LOSS : 35.572------ Time : 24
#
# Epoch : [48/80]----- Iter : [109/109] ----- LOSS : 36.008------ Time : 24
#
# Epoch : [49/80]----- Iter : [109/109] ----- LOSS : 33.220------ Time : 24
#
# Epoch : [50/80]----- Iter : [109/109] ----- LOSS : 32.951------ Time : 23
#
# Epoch : [51/80]----- Iter : [109/109] ----- LOSS : 32.839------ Time : 24
#
# Epoch : [52/80]----- Iter : [109/109] ----- LOSS : 33.203------ Time : 24
#
# Epoch : [53/80]----- Iter : [109/109] ----- LOSS : 30.731------ Time : 24
#
# Epoch : [54/80]----- Iter : [109/109] ----- LOSS : 32.621------ Time : 24
#
# Epoch : [55/80]----- Iter : [109/109] ----- LOSS : 32.382------ Time : 24
#
# Epoch : [56/80]----- Iter : [109/109] ----- LOSS : 33.050------ Time : 24
#
# Epoch : [57/80]----- Iter : [109/109] ----- LOSS : 32.999------ Time : 24
#
# Epoch : [58/80]----- Iter : [109/109] ----- LOSS : 32.237------ Time : 23
#
# Epoch : [59/80]----- Iter : [109/109] ----- LOSS : 32.509------ Time : 24
#
# Epoch : [60/80]----- Iter : [109/109] ----- LOSS : 31.683------ Time : 24
#
# Epoch : [61/80]----- Iter : [109/109] ----- LOSS : 31.500------ Time : 24
#
# Epoch : [62/80]----- Iter : [109/109] ----- LOSS : 31.903------ Time : 23
#
# Epoch : [63/80]----- Iter : [109/109] ----- LOSS : 32.281------ Time : 24
#
# Epoch : [64/80]----- Iter : [109/109] ----- LOSS : 30.978------ Time : 23
#
# Epoch : [65/80]----- Iter : [109/109] ----- LOSS : 32.526------ Time : 24
#
# Epoch : [66/80]----- Iter : [109/109] ----- LOSS : 31.341------ Time : 24
#
# Epoch : [67/80]----- Iter : [109/109] ----- LOSS : 30.636------ Time : 24
#
# Epoch : [68/80]----- Iter : [109/109] ----- LOSS : 31.934------ Time : 24
#
# Epoch : [69/80]----- Iter : [109/109] ----- LOSS : 31.375------ Time : 24
#
# Epoch : [70/80]----- Iter : [109/109] ----- LOSS : 30.819------ Time : 23
#
# Epoch : [71/80]----- Iter : [109/109] ----- LOSS : 31.641------ Time : 23
#
# Epoch : [72/80]----- Iter : [109/109] ----- LOSS : 31.098------ Time : 23
#
# Epoch : [73/80]----- Iter : [109/109] ----- LOSS : 32.360------ Time : 23
#
# Epoch : [74/80]----- Iter : [109/109] ----- LOSS : 31.341------ Time : 23
#
# Epoch : [75/80]----- Iter : [109/109] ----- LOSS : 30.388------ Time : 23
#
# Epoch : [76/80]----- Iter : [109/109] ----- LOSS : 29.622------ Time : 23
#
# Epoch : [77/80]----- Iter : [109/109] ----- LOSS : 29.000------ Time : 24
#
# Epoch : [78/80]----- Iter : [109/109] ----- LOSS : 30.330------ Time : 24
#
# Epoch : [79/80]----- Iter : [109/109] ----- LOSS : 31.332------ Time : 24
#
# Epoch : [80/80]----- Iter : [109/109] ----- LOSS : 30.691------ Time : 24
#
# Starting testing
# Accuracy for fold 5: 87 %
# --------------------------------

# %%
# Print fold results
print(f'K-FOLD CROSS VALIDATION RESULTS FOR {k_folds} FOLDS')
print('--------------------------------')
sum = 0.0
for key, value in results.items():
    print(f'Fold {key}: {value} %')
    sum += value
print(f'Average: {sum/len(results.items())} %')
# Out:
# K-FOLD CROSS VALIDATION RESULTS FOR 5 FOLDS
# --------------------------------
# Fold 1: 87.28323699421965 %
# Fold 2: 88.32369942196532 %
# Fold 3: 87.86127167630057 %
# Fold 4: 88.20809248554913 %
# Fold 5: 87.5 %
# Average: 87.83526011560693 %
